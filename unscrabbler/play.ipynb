# %%
from unscrabbler import WordWarsGame, WWFGame, ScrabbleGame, DOWN, ACROSS

# %%
g = WWFGame()

# %%
g.show()
# Out:
# <style  type="text/css" >
#     #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow0_col3 {
#             background-color:  #ec1c2d;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow0_col6 {
#             background-color:  #7fc8eb;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow0_col8 {
#             background-color:  #7fc8eb;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow0_col11 {
#             background-color:  #ec1c2d;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow1_col2 {
#             background-color:  #7ecaf3;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow1_col5 {
#             background-color:  #faa896;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow1_col9 {
#             background-color:  #faa896;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow1_col12 {
#             background-color:  #7ecaf3;
#         }    #T_fd3450f8_db5c_11ea_aa34_80fa5b4747earow2_col1 {
#             background-color:  #7ecaf3;
# ...

# %%
hand = g.make_hand()
hand
# Out:
# ['N', 'A', 'E', 'U', 'R', 'H', 'G']

# %%
first_moves = g.find_first_moves(hand)[:5]
first_moves[:5]
# Out:
# [('HUNGER', (7, 7), array([0, 1]), 24),
#  ('HUNGER', (7, 6), array([0, 1]), 24),
#  ('HUNGER', (7, 3), array([0, 1]), 24),
#  ('HUNGER', (7, 2), array([0, 1]), 24),
#  ('REHUNG', (7, 7), array([0, 1]), 24)]

# %%
g.play(*first_moves[0][:3])
g.show()
# Out:
# <style  type="text/css" >
#     #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow0_col3 {
#             background-color:  #ec1c2d;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow0_col6 {
#             background-color:  #7fc8eb;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow0_col8 {
#             background-color:  #7fc8eb;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow0_col11 {
#             background-color:  #ec1c2d;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow1_col2 {
#             background-color:  #7ecaf3;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow1_col5 {
#             background-color:  #faa896;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow1_col9 {
#             background-color:  #faa896;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow1_col12 {
#             background-color:  #7ecaf3;
#         }    #T_fd4b0ce8_db5c_11ea_92bc_80fa5b4747earow2_col1 {
#             background-color:  #7ecaf3;
# ...

# %%
hand = g.make_hand()
hand
# Out:
# ['S', 'J', 'I', 'A', 'L', 'N', 'Y']

# %%
top_moves = g.find_moves(hand)
top_moves[:5]
# Out:
# [('LYSIN', array([ 5, 13]), array([1, 0]), 49),
#  ('JAILS', array([ 3, 13]), array([1, 0]), 43),
#  ('JAYS', array([ 4, 13]), array([1, 0]), 43),
#  ('JINS', array([ 4, 13]), array([1, 0]), 41),
#  ('JINNS', array([5, 9]), array([1, 0]), 38)]

# %%
g.play(*top_moves[0][:3])
g.show()
# Out:
# <style  type="text/css" >
#     #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow0_col3 {
#             background-color:  #ec1c2d;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow0_col6 {
#             background-color:  #7fc8eb;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow0_col8 {
#             background-color:  #7fc8eb;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow0_col11 {
#             background-color:  #ec1c2d;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow1_col2 {
#             background-color:  #7ecaf3;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow1_col5 {
#             background-color:  #faa896;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow1_col9 {
#             background-color:  #faa896;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow1_col12 {
#             background-color:  #7ecaf3;
#         }    #T_fdc579d8_db5c_11ea_982c_80fa5b4747earow2_col1 {
#             background-color:  #7ecaf3;
# ...

# %%
g.play('MYTURN', (9, 8), ACROSS)
g.show()
# Out:
# <style  type="text/css" >
#     #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow0_col3 {
#             background-color:  #ec1c2d;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow0_col6 {
#             background-color:  #7fc8eb;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow0_col8 {
#             background-color:  #7fc8eb;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow0_col11 {
#             background-color:  #ec1c2d;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow1_col2 {
#             background-color:  #7ecaf3;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow1_col5 {
#             background-color:  #faa896;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow1_col9 {
#             background-color:  #faa896;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow1_col12 {
#             background-color:  #7ecaf3;
#         }    #T_0ec554ac_db5d_11ea_9e81_80fa5b4747earow2_col1 {
#             background-color:  #7ecaf3;
# ...

# %%
g.play(('',) * 3, (9, 5), ACROSS)

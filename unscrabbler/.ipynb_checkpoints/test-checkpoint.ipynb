# %%
from unscrabbler.core import _Game, ACROSS, DOWN, make_hand, find_spaces, iter_playspace_combos, bonus_format, tree, all_words

# %%
b = _Game()
b.play('opus', (7, 7), ACROSS)
#b.play('arms', (2, 2), ACROSS)
#b.play('fish', (0, 10), DOWN)
b.show()
# Out:
# <style  type="text/css" >
#     #T_722711f6_d0f0_11ea_a409_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_722711f6_d0f0_11ea_a409_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
hand = ['e', 'e', 't', 'a', 't', 'o']
b.show()
# Out:
# <style  type="text/css" >
#     #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_626a6ad2_d0ed_11ea_85e6_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
b.show()
# Out:
# <style  type="text/css" >
#     #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_4b94120a_d0f7_11ea_b04b_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
b.play('mod', (7, 0), ACROSS)
b.show()
# Out:
# <style  type="text/css" >
#     #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_53480e2e_d0f7_11ea_a57f_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
hand = list('tcaese')
top_moves = b.find_top_moves(hand)
top_moves[:5]
# Out:
# [('qats', (11, 0), (1, 0), <(11 - 11) 2-['q']-3>, 39),
#  ('qat', (11, 0), (1, 0), <(11 - 11) 2-['q']-3>, 12),
#  ('feces', (3, 10), (0, 1), <(10 - 11) 10-['f', 'e']-3>, 11),
#  ('cows', (6, 1), (1, 0), <(7 - 11) 7-['o', 'w', None, None, 'u']-3>, 11),
#  ('scow', (5, 1), (1, 0), <(7 - 11) 7-['o', 'w', None, None, 'u']-3>, 11)]

# %%
b.play(*top_moves[0][:3])
b.show()
# Out:
# <style  type="text/css" >
#     #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_e0edcec8_d0f6_11ea_b812_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
print(query.pattern, query.coord, word)
b.show()
# Out:
# [None, None, None, None, 's', None, None, None, None, None, None, None] (3, 11) wants
# <style  type="text/css" >
#     #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_63d375c8_d0ed_11ea_9eab_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
# ...

# %%
list(tree.find_playable([None] * 15, hand, lbuff=0))
# Out:
# ['ad',
#  'at',
#  'pa',
#  'ta',
#  'up',
#  'ut',
#  'apt',
#  'dap',
#  'dup',
#  'jut',
#  'pad',
#  'pat',
#  'pud',
#  'put',
#  'tad',
#  'taj',
#  'tap',
#  'tau',
#  'tup',
#  'uta',
#  'daut',
#  'jaup',
#  'puja']

# %%
'yetties' in all_words
# Out:
# False

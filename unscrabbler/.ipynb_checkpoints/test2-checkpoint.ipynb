# %%
from unscrabbler.core import WordWarsGame, DOWN, ACROSS, iter_playspace_combos, find_spaces
import pandas as pd
g = WordWarsGame()
#g.play('o', (8, 8), DOWN)

# %%
banned = ['moireing', 
          'ji', 
          'ot', 
          'ext',
          'jt', 
          'iddhi',
          'decoic', 
          'dioc', 
          'cy', 
          'esnecy', 
          'le', 
          'cre', 
          'enl', 
          'harre',
          'lehay',
          'cle',
          'angula',
          'vagas',
          'fei',
          'ux',
          'fruz',
          'buz',
          'guz',
          'xii',
          'xr',
          'xx',
          'suz',
          'xw',
          'il',
          'pinic',
          'gv',
          'doke',
          'meio',
          'ie',
          'determ',
          'ty',
          'moha',
          'tiao',
          'ia',
          'ote',
          'sotie',
          'xvi',
          'xiv',
          'jarvy',
          'zar',
          'seq',
          'qu',
          'secque',
          'coque',
          'ocque',
          'qto',
          'qts',
          'scote',
          'esque',
          'akre',
          'ck',
          'tk',
          'spuke',
          'skulp',
          'usu',
          'chulha',
          'khula',
          'witan',
          'yr',
          'quae',
          'quo',
          'ry',
          'sy',
          'ey',
          'phr']

for b in banned:
    break
    try:
        g.all_words.remove(b)
    except ValueError:
        pass
g.word_tree.tree = {}
g.word_tree.build_tree(g.all_words)

# %%
g.show()
# Out:
# <style  type="text/css" >
#     #T_b8146280_d440_11ea_9526_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_b8146280_d440_11ea_9526_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
g.play('ezine', (0, 13), DOWN)
g.show()
# Out:
# <style  type="text/css" >
#     #T_87e32258_d43e_11ea_8595_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_87e32258_d43e_11ea_8595_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
hand = list('u?lahnh')
print(hand)
top_moves = g.find_top_moves(hand, top=None)
#top_moves.sort(key=lambda w: w[-1], reverse=True)
top_moves[:10]
# Out:
# ['u', '?', 'l', 'a', 'h', 'n', 'h']
# [('zho',
#   (7, 3),
#   (0, 1),
#   <(5 - 12) 3-['o', None, 'v', 'i', 'v', 'a', 'r', 'y']-2>,
#   (((7, 5), (1, 0), 'oobit'),),
#   25),
#  ('ye',
#   (12, 12),
#   (1, 0),
#   <(13 - 13) 4-['e']-1>,
#   (((12, 11), (0, 1), 'oy'), ((13, 7), (0, 1), 'unpriest')),
#   20),
#  ('oy',
#   (12, 11),
#   (0, 1),
#   <(11 - 14) 2-['o', None, None, 'i']-0>,
#   (((11, 11), (1, 0), 'coif'), ((12, 12), (1, 0), 'ye')),
#   20),
#  ('juha',
#   (4, 5),
#   (0, 1),
#   <(10 - 14) 10-['t', None, 's', 'e', 'e']-0>,
#   (((4, 8), (1, 0), 'ae'),),
#   19),
#  ('xs',
#   (12, 13),
#   (1, 0),
#   <(13 - 13) 7-['s']-1>,
#   (((12, 13), (0, 1), 'xi'), ((13, 7), (0, 1), 'unpriest')),
#   18),
#  ('xi',
#   (12, 13),
#   (0, 1),
#   <(14 - 14) 1-['i']-0>,
#   (((12, 13), (1, 0), 'xs'), ((9, 14), (1, 0), 'recite')),
#   18),
#  ('whr',
#   (9, 12),
#   (0, 1),
#   <(14 - 14) 2-['r']-0>,
#   (((9, 14), (1, 0), 'recite'),),
#   17),
#  ('xix',
#   (9, 9),
#   (0, 1),
# ...

# %%
g.play(*top_moves[0][:3])
g.show()
# Out:
# <style  type="text/css" >
#     #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_824441e8_d43e_11ea_9bf8_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
top_moves = g.find_top_first_move(list('?myavri'))
top_moves
# Out:
# [('jar', (7, 3), (0, 1), 22),
#  ('jai', (7, 3), (0, 1), 22),
#  ('ziram', (7, 6), (0, 1), 17),
#  ('ziram', (7, 7), (0, 1), 17),
#  ('vivary', (7, 6), (0, 1), 17),
#  ('vivary', (7, 7), (0, 1), 17),
#  ('jiva', (7, 7), (0, 1), 17),
#  ('ziram', (7, 5), (0, 1), 17),
#  ('hvy', (7, 3), (0, 1), 17),
#  ('xi', (7, 3), (0, 1), 17)]

# %%
g.calc_word_score('vetures', (7, 7), ACROSS)
# Out:
# 12

# %%
g.show()
# Out:
# <style  type="text/css" >
#     #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_9aa830e8_d400_11ea_aa6d_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
'yug' in g.all_words
# Out:
# False

# %%
g.play(*top_moves[0][:3])
g.show()
# Out:
# <style  type="text/css" >
#     #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow0_col0 {
#             background-color:  #ec1c2d;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow0_col3 {
#             background-color:  #7ecaf3;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow0_col7 {
#             background-color:  #ec1c2d;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow0_col11 {
#             background-color:  #7ecaf3;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow0_col14 {
#             background-color:  #ec1c2d;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow1_col1 {
#             background-color:  #faa896;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow1_col5 {
#             background-color:  #7fc8eb;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow1_col9 {
#             background-color:  #7fc8eb;
#         }    #T_9ab4de7a_d400_11ea_b142_80fa5b4747earow1_col13 {
#             background-color:  #faa896;
# ...

# %%
'o' in all_words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8f96d022a967> in <module>
# ----> 1 'o' in all_words
#
# NameError: name 'all_words' is not defined

# %%
g.save('WWs.scrab')

# %%
b.grid.values
